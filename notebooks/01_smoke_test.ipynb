# %%
import pandas as pd

df = pd.read_csv("C:/Users/User/python-env-RawanQuraish/data/sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (5, 3)
#        name  age  passed
# 0     Ahmad   25    True
# 1     Hanan   32   False
# 2      Sara   30   False
# 3  Mohammad   28    True
# 4     Rawan   31    True
#              age
# count   5.000000
# mean   29.200000
# std     2.774887
# min    25.000000
# 25%    28.000000
# 50%    30.000000
# 75%    31.000000
# max    32.000000
